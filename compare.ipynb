# %%
import pandas as pd

# %%
df = pd.read_csv("out/summary.csv")

# %%
df["solver_1"] = df["pair"].apply(lambda s: s.split("-")[0])
df["solver_2"] = df["pair"].apply(lambda s: s.split("-")[1])

# %%
df["solver_time_1"] = df["solver_end_1"] - df["solver_start_1"]
df["solver_time_2"] = df["solver_end_2"] - df["solver_start_2"]

# %%
df = df[df["timeout"] == False]

# %%
df = df[df["pair"] == "fwd-wbu"]

# %%
df
# Out:
#     returncode  timeout  solver_start_1  solver_end_1  solver_start_2  \
# 2            0    False   1771606803858  1.771607e+12    1.771607e+12
# 3            0    False   1771606803388  1.771607e+12    1.771607e+12
# 8            0    False   1771606803415  1.771607e+12    1.771607e+12
# 10           0    False   1771606803407  1.771607e+12    1.771607e+12
# 14           0    False   1771606803823  1.771607e+12    1.771607e+12
# 16           0    False   1771606803418  1.771607e+12    1.771607e+12
# 17           0    False   1771606803884  1.771607e+12    1.771607e+12
# 22           0    False   1771606803872  1.771607e+12    1.771607e+12
# 27           0    False   1771606803841  1.771607e+12    1.771607e+12
# 29           0    False   1771606803890  1.771607e+12    1.771607e+12
#
#     solver_end_2  globals_equal  globals_left  globals_right  \
# 2   1.771607e+12          561.0           0.0            0.0
# 3   1.771607e+12          324.0           1.0            2.0
# ...
